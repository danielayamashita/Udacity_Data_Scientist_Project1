# %% [markdown]
# ### Project 1: Write a Data Scientist Blog Post
#
# This Jupyter notebook will analyse the StackOverflow data from 2011 to 2020 to indentify some tendencies in software developper career satisfaction in the last years.
#
# First of all, the data are read from csv files.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Read csv files
PathName = "./Dataset/"
FileNames = ["2011 Stack Overflow Survey Results",
             "2012 Stack Overflow Survey Results",
             "2013 Stack Overflow Survey Responses",
             "2014 Stack Overflow Survey Responses",
             "2015 Stack Overflow Developer Survey Responses",
             "2016 Stack Overflow Survey Responses",
             "survey_results_public_2017",
             "survey_results_public_2018",
            "survey_results_public_2019",
            "survey_results_public_2020"]

# %%
years = np.linspace(2011,2020,2020-2011+1,dtype = 'int')

Education_field = ['',
                   '',
                   '',
                   '',
                   '',
                   '',
                   'FormalEducation',
                   'FormalEducation',
                   'UndergradMajor',
                   'EdLevel']

Language_field = ['Which languages are you proficient in?',
                   'Which languages are you proficient in?',
                   'Which of the following languages or technologies have you used significantly in the past year?',
                   'Which of the following languages or technologies have you used significantly in the past year?',
                   'Select all that apply.1',
                   '',
                   'HaveWorkedLanguage',
                   'LanguageWorkedWith',
                   'LanguageWorkedWith',
                   'LanguageWorkedWith']
work_remotely = ['',
                '',
                '',
                'Do you work remotely?',
                '',
                '',
                'HomeRemote',
                '',
                'WorkRemote',
                '']

# %% [markdown]
# Evaluate the evolution in the last years on programming language usage.

# %%
def show_top_five_programming_languages(language,year,show_results = False):
    print('Parse language field...')
    
    # Drop empty lines
    language = language.dropna(axis = 0)
    
    # Identify the type of languages used in a year
    All_languages = []
    for sublist in language.str.split(";",expand=False).values.tolist():
        for item in sublist:
            All_languages.append(item.replace(" ", ""))

    language_type = list(set(All_languages)) # Select unique type of languages

    # Calculate the frequency of each type of language
    language_frequency =[]
    for language_type_ in range(len(language_type)):
        language_frequency.append(All_languages.count(language_type[language_type_]))


    # Sort in decreasing order the most used programming language
    index_sort = np.argsort(language_frequency)
    index_sort
    language_type_sorted = []
    language_frequency_sorted = []
    for index in index_sort:
        language_type_sorted.append(language_type[index])
        language_frequency_sorted.append(language_frequency[index])

    # Show frequency bar for the top 5
    if show_results:
        fig = plt.figure()
        ax = fig.add_axes([0,0,1,1])
        ax.bar(language_type_sorted[-5:],language_frequency_sorted[-5:])
        plt.title('The five most popular programming language in ' + str(year))
        plt.show()
    return language

# %%
years = [2017]

for year in years:
    idx =  year - 2011;
    print('------------------------------------------------------------------------')
    print('Year ' + str(year))
    print("Reading csv file ': " + PathName  + FileNames[idx] + '.csv ...')
    df = pd.read_csv(PathName  + FileNames[idx] + '.csv',engine='python') # TODO: Uncomment it later
    if Language_field[idx] != '':
        print('Analysing field ' + Language_field[idx] + '...')
        language = df[Language_field[idx]]
        language = show_top_five_programming_languages(language,year,show_results = True)
    else:
        language = []
        print('The field is empty! ')
            
language
# Out:
# ------------------------------------------------------------------------
# Year 2017
# Reading csv file ': ./Dataset/survey_results_public_2017.csv ...
# Analysing field HaveWorkedLanguage...
# Parse language field...
# 0                                                    Swift
# 1                            JavaScript; Python; Ruby; SQL
# 2                                        Java; PHP; Python
# 3                                   Matlab; Python; R; SQL
# 5                                    JavaScript; PHP; Rust
# 6                                           Matlab; Python
# 7        CoffeeScript; Clojure; Elixir; Erlang; Haskell...
# 8                                           C#; JavaScript
# 9                                       Objective-C; Swift
# 10                                                  R; SQL
# 12                                            C; C++; Java
# 13                             Java; JavaScript; Ruby; SQL
# 14                                        Assembly; C; C++
# 15                                      JavaScript; VB.NET
# 16                                              JavaScript
# 17        C; Clojure; JavaScript; Matlab; Rust; SQL; Swift
# 19                                            Perl; Python
# 21                                     C#; JavaScript; SQL
# 22                                                    Java
# 23                                                PHP; SQL
# 25                                             Java; Scala
# 26            Java; JavaScript; Objective-C; Python; Swift
# 28                                      JavaScript; Python
# 32                                                C#; Java
# 33                                              JavaScript
# 34                                             Assembly; C
# 35                       C#; JavaScript; Matlab; Python; R
# 36                                 C#; F#; JavaScript; SQL
# 37                                    C#; Java; JavaScript
# 38                         C#; JavaScript; SQL; TypeScript
# 40                         C; C++; JavaScript; Lua; Python
# 42                                   Java; JavaScript; SQL
# 44                              Java; JavaScript; SQL; VBA
# 45                            C; C++; Groovy; Java; Python
# 47                     C++; C#; Java; JavaScript; Lua; SQL
# 48                                        JavaScript; Ruby
# 49                                           C#; Java; SQL
# 50                                              JavaScript
# 51                  Assembly; C++; Groovy; Java; Perl; SQL
# 52                             Java; JavaScript; PHP; Ruby
# 53                                        Java; JavaScript
# 54                                   Java; JavaScript; PHP
# 55                      Java; JavaScript; PHP; SQL; VB.NET
# 56                                                      C#
# 57                                                Go; Java
# 58                                     C#; JavaScript; SQL
# 60                                                      C#
# 61                                     C#; JavaScript; SQL
# 62                                                     PHP
# 63       C++; C#; Java; JavaScript; Python; Ruby; SQL; ...
# 64               C; C++; C#; Java; JavaScript; Matlab; SQL
# 65                                              JavaScript
# 66                                    C++; C#; Objective-C
# 67                                     C; C++; Python; SQL
# 68                     CoffeeScript; JavaScript; Ruby; SQL
# 70                          CoffeeScript; JavaScript; Ruby
# 71                            JavaScript; PHP; Python; SQL
# 72                                     C#; JavaScript; SQL
# 73                           Elixir; Java; JavaScript; SQL
# 75       Assembly; C; C++; Java; JavaScript; Perl; Pyth...
# 76                                          C#; JavaScript
# 80       C#; JavaScript; PHP; Python; SQL; TypeScript; ...
# 81                                               Java; SQL
# 82                                C++; C#; JavaScript; SQL
# 83                                C; C++; Java; JavaScript
# 88                            Java; PHP; Python; Ruby; SQL
# 89                                       JavaScript; Scala
# 90                                   C; JavaScript; Python
# 91          CoffeeScript; Haskell; JavaScript; Python; SQL
# 93                                                      C#
# 94                                              C; C#; SQL
# 95                             JavaScript; Ruby; Smalltalk
# 96             C#; JavaScript; SQL; VB.NET; Visual Basic 6
# 97                              C#; JavaScript; TypeScript
# 99                         C; Go; Objective-C; Ruby; Swift
# 100                                            Java; Scala
# 102                                                C++; C#
# 103                                                 Python
# 104                           Java; VB.NET; Visual Basic 6
# 105      C; C#; Common Lisp; Clojure; Java; JavaScript;...
# 106                                            C#; Go; SQL
# 107                                              C; Python
# 108                                                     C#
# 109                          JavaScript; Python; Ruby; SQL
# 110                         CoffeeScript; JavaScript; Ruby
# 111                               C; C++; JavaScript; Perl
# 112                                              Java; SQL
# 113                                                C++; C#
# 114                                                     C#
# 115                                         C#; JavaScript
# 116                                  Java; JavaScript; SQL
# 117                                                 VB.NET
# 118      CoffeeScript; JavaScript; Objective-C; PHP; Py...
# 121          C#; Java; JavaScript; Python; SQL; TypeScript
# 122                               C#; JavaScript; PHP; SQL
# 123                                                C#; SQL
# 124                     Java; JavaScript; Lua; PHP; R; SQL
# 125                                          C++; C#; Java
# 126                      C#; Java; JavaScript; Python; SQL
# 130                       C#; JavaScript; Matlab; PHP; SQL
# 131                                                    C++
# 132             CoffeeScript; JavaScript; PHP; Python; SQL
# 133      C++; Java; JavaScript; Matlab; Objective-C; Py...
# 134                               C#; JavaScript; PHP; SQL
# 135                                                   Ruby
# 136                        C#; JavaScript; SQL; TypeScript
# 142                                      C; C#; JavaScript
# 143                      C++; C#; F#; Haskell; Python; SQL
# 146          C#; Java; JavaScript; Python; Scala; SQL; VBA
# 148                                                    SQL
# 149                   C; C++; C#; F#; Haskell; Java; Swift
# 153                                                 Python
# 154                                            Matlab; VBA
# 155                            Java; JavaScript; Perl; SQL
# 156                           Java; JavaScript; TypeScript
# 157                                    C#; JavaScript; SQL
# 158                             JavaScript; PHP; Ruby; SQL
# 159                                     JavaScript; Python
# 161                                         C; C++; Python
# 162         C#; Java; JavaScript; Python; Ruby; Scala; SQL
# 165                                         Go; JavaScript
# 166                           Java; PHP; Python; Ruby; SQL
# 167                                      JavaScript; Scala
# 168      C#; Java; JavaScript; Python; Scala; SQL; Type...
# 169                                   JavaScript; PHP; SQL
# 170               Java; JavaScript; Perl; PHP; Python; SQL
# 172                                    Go; JavaScript; SQL
# 173                     Elixir; Java; JavaScript; PHP; SQL
# 174                          Common Lisp; Java; JavaScript
# 175                         C; C#; JavaScript; Python; SQL
# 176                                 C#; Objective-C; Swift
# 177            C#; Java; JavaScript; PHP; Ruby; SQL; Swift
# 178                       C; Java; JavaScript; PHP; Python
# 179                                     JavaScript; Python
# 180                                 JavaScript; TypeScript
# 181                                          C++; C#; Perl
# 182                                             JavaScript
# 183                                              Java; SQL
# 184                     CoffeeScript; JavaScript; PHP; SQL
# 185                C#; F#; Go; JavaScript; Scala; SQL; VBA
# 189                                     Objective-C; Swift
# 190                          Java; JavaScript; Python; SQL
# 191                                  Java; JavaScript; PHP
# 192            CoffeeScript; Elixir; JavaScript; Ruby; SQL
# 193                                             JavaScript
# 195                                         C#; JavaScript
# 196                                  C++; Java; JavaScript
# 197                                    C#; JavaScript; SQL
# 198                   C++; Java; Objective-C; Perl; Python
# 206                          Groovy; Java; JavaScript; SQL
# 207                 C; Java; JavaScript; Perl; Python; SQL
# 209                                    C#; JavaScript; SQL
# 210                C#; Java; JavaScript; Perl; Python; SQL
# 211                                    C#; JavaScript; SQL
# 212                                   JavaScript; PHP; SQL
# 214                                                 Python
# 215                           Go; JavaScript; Python; Ruby
# 216                                                C#; SQL
# 218                               C#; JavaScript; SQL; VBA
# 220                       CoffeeScript; JavaScript; Python
# 221                                                     C#
# 222                                          C#; Java; SQL
# 223                        C#; JavaScript; SQL; TypeScript
# 224                            C#; JavaScript; Python; SQL
# 225                          Groovy; Java; JavaScript; SQL
# 228                              C#; Java; JavaScript; SQL
# 229                                                    C++
# 230                 Java; JavaScript; Python; Scala; Swift
# 232      Go; Java; JavaScript; Python; Ruby; Rust; SQL;...
# 234                                   C#; Dart; JavaScript
# 235                                              C; VB.NET
# 237                                    C#; JavaScript; SQL
# 238                                                    SQL
# 241                            C++; Matlab; Python; R; VBA
# 242      Assembly; C; C++; Common Lisp; Java; JavaScrip...
# 246                           JavaScript; PHP; Python; SQL
# 247                                                    C++
# 249                        C#; Java; JavaScript; Perl; SQL
# 250                                                   Java
# 252                                     Objective-C; Swift
# 253                                                     C#
# 254             C; C++; Java; JavaScript; PHP; Python; SQL
# 255                                JavaScript; Python; SQL
# 256                                      Java; Lua; Python
# 257                           Assembly; C; C++; JavaScript
# 258                       Assembly; C; C++; C#; SQL; Swift
# 260                               C#; JavaScript; SQL; VBA
# 264                            Java; JavaScript; Perl; SQL
# 265      C; C++; C#; CoffeeScript; Haskell; JavaScript;...
# 266      Assembly; C; C++; C#; Go; Java; JavaScript; Lu...
# 267                                         C#; JavaScript
# 271      C++; C#; Java; JavaScript; Lua; PHP; Python; S...
# 272                                       C++; Objective-C
# 273                                       Java; JavaScript
# 274                            JavaScript; SQL; TypeScript
# 275                                            C++; Python
# 276                                                C++; C#
# 278                                                C#; SQL
# 279      Go; Groovy; Java; JavaScript; Python; Ruby; Sc...
# 280                                              Java; PHP
# 281                                    C#; JavaScript; SQL
# 282                                             JavaScript
# 283                   Assembly; Java; JavaScript; PHP; SQL
# 284                          Java; JavaScript; PHP; Python
# 285                              C#; Java; JavaScript; SQL
# 286                               C#; JavaScript; PHP; SQL
# 287                                                    SQL
# 288                             C; C++; JavaScript; Python
# 289                  Assembly; C; Erlang; Go; Java; Python
# 290                     Java; JavaScript; PHP; Python; SQL
# 291                  Objective-C; Python; Ruby; SQL; Swift
# 292      C#; CoffeeScript; JavaScript; PHP; SQL; TypeSc...
# 294             Assembly; C; C++; C#; Java; Matlab; Python
# 295                                   C++; C#; Objective-C
# 296                           C#; Java; JavaScript; VB.NET
# 297                                   Python; R; Ruby; SQL
# 298      C; Java; JavaScript; Lua; PHP; SQL; VBA; Visua...
# 299                                        JavaScript; PHP
# 300                              C#; JavaScript; Ruby; SQL
# 303                                JavaScript; PHP; Python
# 304                                                  Scala
# 305                                     JavaScript; Python
# 306                                    C#; JavaScript; SQL
# 307                          Assembly; C++; Matlab; Python
# 308                                                   Ruby
# 309                                     JavaScript; Python
# 310           C#; JavaScript; PHP; SQL; TypeScript; VB.NET
# 312                                                    PHP
# 313                                                 Python
# 314                                   JavaScript; PHP; SQL
# 315                         CoffeeScript; JavaScript; Ruby
# 316                                       Erlang; F#; Java
# 317                                                C#; SQL
# 318                 C#; Java; JavaScript; Objective-C; SQL
# 320                                     C; C++; C#; Python
# 322                              Java; Matlab; Python; SQL
# 323                                  Java; JavaScript; SQL
# 324               C#; Go; JavaScript; Lua; SQL; TypeScript
# 326                          Groovy; Java; JavaScript; SQL
# 327                                 C#; Objective-C; Swift
# 328              C++; JavaScript; Python; Ruby; Scala; SQL
# 329                                                C++; C#
# 330                           C++; Objective-C; PHP; Swift
# 331                                  Java; JavaScript; SQL
# 334                                   JavaScript; PHP; SQL
# 335                                       Go; Python; Ruby
# 336                                      C++; Java; Python
# 338                                  Java; JavaScript; SQL
# 340      C; C#; Groovy; Java; JavaScript; Ruby; Scala; ...
# 341                                   Java; Python; R; SQL
# 342      CoffeeScript; Elixir; JavaScript; PHP; Python;...
# 343                                                   Java
# 344                  CoffeeScript; Java; JavaScript; Swift
# 345                  C#; Java; JavaScript; SQL; TypeScript
# 347                                                  Swift
# 349                                    C#; JavaScript; SQL
# 350                 C#; Java; JavaScript; Python; SQL; VBA
# 351              C++; Java; JavaScript; Python; TypeScript
# 352                       Groovy; Java; Python; Scala; SQL
# 355                                             JavaScript
# 357                                         C#; JavaScript
# 359                            C#; JavaScript; Python; SQL
# 360                               Java; JavaScript; Python
# 362                                     C++; C#; Rust; SQL
# 363      C; C++; Java; JavaScript; Objective-C; PHP; Sc...
# 364                 C; C++; C#; Go; JavaScript; TypeScript
# 365                                              C; Python
# 366                                                 C#; F#
# 370                                    C#; JavaScript; SQL
# 371                                              Java; SQL
# 372           C; Common Lisp; JavaScript; PHP; Python; SQL
# 373                                    C#; JavaScript; SQL
# 374                                 C#; JavaScript; Python
# 376                                             JavaScript
# 378      CoffeeScript; Haskell; Java; JavaScript; Ruby;...
# 380               C#; JavaScript; PHP; Python; SQL; VB.NET
# 385                                   JavaScript; PHP; SQL
# 386                                  C#; Java; Python; SQL
# 387                                                   Java
# 388                   C; C++; Java; JavaScript; TypeScript
# 390                               C#; JavaScript; PHP; SQL
# 391                            C#; JavaScript; Perl; Swift
# 394        Java; JavaScript; PHP; SQL; VBA; Visual Basic 6
# 395                             C#; JavaScript; TypeScript
# 396                                  Java; JavaScript; SQL
# 397                                    C#; JavaScript; SQL
# 398                           C++; C#; F#; JavaScript; SQL
# 399                                            C; C++; SQL
# 400                                                   Ruby
# 401                                    Objective-C; Python
# 402                                       JavaScript; Perl
# 405             C++; C#; JavaScript; PHP; SQL; VB.NET; VBA
# 406                                           C++; C#; SQL
# 407                                                     C#
# 408                                        C#; Python; SQL
# 410                                   JavaScript; PHP; SQL
# 412                                            Groovy; PHP
# 414                                        C; C#; PHP; SQL
# 417           Assembly; C; C++; JavaScript; Matlab; Python
# 418                                  Java; JavaScript; SQL
# 419                               C#; JavaScript; PHP; SQL
# 420                                JavaScript; Python; SQL
# 422                                                     C#
# 425                                            Java; Scala
# 426                                C#; SQL; Visual Basic 6
# 428                                                   Java
# 429                                     C; JavaScript; SQL
# 430                                            C; C++; Lua
# 431                          Groovy; Java; JavaScript; SQL
# 432                      Assembly; C; Java; Matlab; Python
# 433                                                C#; SQL
# 434      Assembly; C; C++; Java; Objective-C; PHP; Pyth...
# 435                                C++; JavaScript; Python
# 436                               C++; C#; JavaScript; SQL
# 437                                       Java; JavaScript
# 438                                  Java; JavaScript; SQL
# 439                 C; Java; JavaScript; Perl; Python; SQL
# 440                                   C++; Haskell; Python
# 441      Assembly; C; C++; C#; Java; JavaScript; PHP; P...
# 443                                  Java; JavaScript; SQL
# 444                                  Java; JavaScript; SQL
# 446                                         C#; JavaScript
# 447                                             C; C++; C#
# 448                                                     C#
# 449                                   Go; JavaScript; Ruby
# 450                     C; C++; C#; Java; Lua; Python; SQL
# 451                                                     Go
# 452                                   JavaScript; PHP; SQL
# 453                       Assembly; C#; Java; Python; Ruby
# 454                                                    PHP
# 457                                   C; C++; Java; Python
# 458      Java; JavaScript; Matlab; PHP; SQL; VB.NET; VB...
# 460           C#; JavaScript; SQL; TypeScript; VB.NET; VBA
# 461                                                 Python
# 463                                             JavaScript
# 466                                    C#; JavaScript; SQL
# 467                                           Java; Python
# 468                                       Assembly; C; C++
# 469                                             JavaScript
# 470                                    C#; SQL; TypeScript
# 471      C#; Java; Matlab; PHP; Python; SQL; VB.NET; VB...
# 472                                    C#; JavaScript; SQL
# 474                                             C; C++; C#
# 475                                     JavaScript; Python
# 476             CoffeeScript; Elixir; JavaScript; PHP; SQL
# 477                                     C#; Matlab; Python
# 479                                  C++; Java; JavaScript
# 481                                                C#; SQL
# 482      C; Common Lisp; Elixir; Erlang; Java; JavaScri...
# 484                                        JavaScript; PHP
# 488                                       C; C++; PHP; SQL
# 489                 C++; C#; Java; JavaScript; Python; SQL
# 490               C#; Java; JavaScript; Objective-C; Swift
# 491                                                   Java
# 492                        C#; JavaScript; SQL; TypeScript
# 493                                         C++; Python; R
# 494                                   JavaScript; PHP; SQL
# 495                                                    PHP
# 496              Java; JavaScript; PHP; Python; TypeScript
# 497                                             JavaScript
# 499                              C#; Java; JavaScript; SQL
# 500      C; C++; C#; Java; JavaScript; Matlab; Objectiv...
# 501                            C#; JavaScript; Python; SQL
# 502                               C#; JavaScript; PHP; SQL
# 503                                    C#; JavaScript; SQL
# 504            C#; JavaScript; PHP; SQL; Swift; TypeScript
# 505                      C; C++; Java; Perl; Python; Swift
# 506                         Clojure; Python; R; Scala; SQL
# 507                                   C#; Java; JavaScript
# 508                                  C#; Python; Ruby; SQL
# 509                               C++; C#; JavaScript; SQL
# 510                        C#; JavaScript; SQL; TypeScript
# 511                                               C; Swift
# 512      C#; CoffeeScript; Java; JavaScript; Objective-...
# 514                                         C#; JavaScript
# 515                          Java; JavaScript; Perl; Scala
# 516      C; C++; C#; Java; JavaScript; Objective-C; SQL...
# 517                                 C; C#; JavaScript; SQL
# 518                                         C#; JavaScript
# 521                                       JavaScript; Ruby
# 522                                                C#; SQL
# 524                                               C#; Java
# 525                                     Objective-C; Swift
# 528                                        JavaScript; SQL
# 529                            C#; JavaScript; SQL; VB.NET
# 530                                                Clojure
# 531                                C; C++; JavaScript; SQL
# 532                                                 Python
# 533                                  JavaScript; PHP; Ruby
# 534                                             JavaScript
# 535                                            SQL; VB.NET
# 536                            C#; JavaScript; Python; SQL
# 539                                            Python; SQL
# 541                                           Java; Python
# 545                  Elixir; JavaScript; PHP; Python; Ruby
# 546                              JavaScript; PHP; SQL; VBA
# 548                  C#; JavaScript; Ruby; SQL; TypeScript
# 552                                   Clojure; Python; VBA
# 554                                                 Python
# 557                  C#; Java; JavaScript; SQL; TypeScript
# 558                                 JavaScript; TypeScript
# 560                                       Java; TypeScript
# 561                                JavaScript; Python; SQL
# 562                                                     C#
# 563                                   JavaScript; PHP; SQL
# 564                                          C++; C#; Java
# 565                C#; JavaScript; Python; SQL; TypeScript
# 567                                  Java; JavaScript; SQL
# 568                                      C++; Java; Python
# 570           Assembly; C; C++; Objective-C; Python; Swift
# 571                               C; C++; Objective-C; VBA
# 572                             Java; JavaScript; Lua; SQL
# 574                                        JavaScript; PHP
# 575                                    C#; JavaScript; SQL
# 576                                       Java; JavaScript
# 577                                    C#; JavaScript; SQL
# 578                                       JavaScript; Ruby
# 579                                                  C; C#
# 580                          Groovy; Java; JavaScript; SQL
# 581                                Java; JavaScript; Scala
# 582                                  Java; JavaScript; SQL
# 584      Assembly; C++; C#; F#; Java; JavaScript; PHP; ...
# 585                        C#; JavaScript; Perl; Ruby; SQL
# 586                              Clojure; JavaScript; Ruby
# 587                               Java; JavaScript; Python
# 589                  C++; C#; Java; JavaScript; Scala; SQL
# 590             C++; Java; JavaScript; Matlab; Python; SQL
# 591                               Assembly; C; C++; Python
# 592                            C#; JavaScript; SQL; VB.NET
# 593                          Java; JavaScript; Matlab; SQL
# 594      C; C++; C#; JavaScript; PHP; Python; SQL; VBA;...
# 595                                                   Java
# 597        CoffeeScript; Java; JavaScript; Perl; PHP; Ruby
# 598                                      C++; C#; PHP; SQL
# 599                                       JavaScript; Ruby
# 600                                                     C#
# 603                        C#; JavaScript; SQL; TypeScript
# 604      C; C++; CoffeeScript; Common Lisp; JavaScript;...
# 605                                             JavaScript
# 606                                        C#; SQL; VB.NET
# 608                    C#; F#; JavaScript; SQL; TypeScript
# 609                                Java; Python; Ruby; SQL
# 610                                             JavaScript
# 611                                C#; SQL; Visual Basic 6
# 612                                    C++; Matlab; Python
# 613                           C#; F#; JavaScript; PHP; SQL
# 614                                          C++; C#; Java
# 616                                            PHP; Python
# 617                                                     C#
# 618       C++; C#; Go; Java; JavaScript; Python; Ruby; SQL
# 621      Clojure; Java; JavaScript; Perl; Python; Scala...
# 623                                       Java; JavaScript
# 624       C; C++; C#; Clojure; JavaScript; SQL; TypeScript
# 625                                       JavaScript; Ruby
# 626                                    C++; Matlab; Python
# 627                      C++; JavaScript; PHP; Python; SQL
# 628                                   JavaScript; PHP; SQL
# 633                          Groovy; Java; JavaScript; SQL
# 634                                 C#; JavaScript; Python
# 635        C++; Java; JavaScript; Matlab; PHP; Python; SQL
# 641                         CoffeeScript; JavaScript; Ruby
# 643                                       Java; JavaScript
# 645                                              Ruby; SQL
# 646                                                 C; C++
# 647      C; C++; C#; JavaScript; Lua; Objective-C; Pyth...
# 648           C; C#; Java; JavaScript; Python; SQL; VB.NET
# 649                                      C++; Perl; Python
# 650                                        JavaScript; PHP
# 651                                   C; C++; Python; Ruby
# 653             CoffeeScript; JavaScript; Ruby; SQL; Swift
# 655                               Clojure; Java; Lua; Rust
# 656                               C#; JavaScript; PHP; SQL
# 657            C; C++; C#; JavaScript; Python; SQL; VB.NET
# 658                                C#; Python; R; SQL; VBA
# 663                                             C++; Swift
# 664                                 JavaScript; TypeScript
# 666            CoffeeScript; JavaScript; PHP; Python; Ruby
# 668                                    C#; JavaScript; SQL
# 669                                   JavaScript; PHP; SQL
# 670            C++; Groovy; Java; Python; Ruby; Scala; SQL
# 673                               Objective-C; Ruby; Swift
# 674                                   JavaScript; PHP; SQL
# 678            Groovy; Java; JavaScript; Objective-C; Perl
# 680                               C#; JavaScript; PHP; SQL
# 681                                              Java; SQL
# 682                                      C; C++; Python; R
# 684                          C; Java; JavaScript; PHP; SQL
# 685                                          C; JavaScript
# 686                                    C#; JavaScript; SQL
# 687                              Erlang; JavaScript; Scala
# 688                     C#; JavaScript; Python; TypeScript
# 689                               Go; JavaScript; PHP; SQL
# 690                            C#; JavaScript; SQL; VB.NET
# 691                                   JavaScript; PHP; SQL
# 693           C#; Java; JavaScript; Perl; PHP; Python; SQL
# 694                                                C++; C#
# 696                               Java; JavaScript; Python
# 697                      Java; JavaScript; PHP; Scala; SQL
# 701                                            C#; F#; SQL
# 702                                                      C
# 703                  Elixir; Go; Java; Python; Ruby; Scala
# 704                                     C; JavaScript; SQL
# 706                               Java; JavaScript; Matlab
# 707                                                C#; SQL
# 708                                                     C#
# 709                                            Python; SQL
# 710                                       C++; Python; SQL
# 711      C#; Java; JavaScript; Python; SQL; Visual Basic 6
# 712                                                   Java
# 713                                         C; C++; Python
# 714                          CoffeeScript; JavaScript; SQL
# 715                                            C; C++; Lua
# 717              Java; JavaScript; Python; SQL; TypeScript
# 718                        C++; Java; JavaScript; PHP; SQL
# 719                                              Java; SQL
# 721                       JavaScript; Python; Ruby; VB.NET
# 722      C++; C#; CoffeeScript; Go; JavaScript; Ruby; S...
# 723      Assembly; C; C++; Go; JavaScript; Perl; PHP; S...
# 724                       C#; JavaScript; PHP; SQL; VB.NET
# 725                                             C#; R; SQL
# 727                                   JavaScript; PHP; SQL
# 728                       Java; JavaScript; Matlab; R; SQL
# 730                C#; Go; Java; JavaScript; Python; Scala
# 731                  Assembly; C; Erlang; Java; JavaScript
# 732                                              Java; SQL
# 733                           Clojure; Groovy; Java; Scala
# 734                Go; JavaScript; Python; SQL; TypeScript
# 735               CoffeeScript; JavaScript; PHP; Ruby; SQL
# 736                                C#; Java; Python; Scala
# 737                              C#; Python; R; Scala; SQL
# 738                                            C#; F#; Lua
# 740                                                   Java
# 742                              Elixir; Java; Python; SQL
# 743                       Java; JavaScript; Python; R; SQL
# 744                                                C++; C#
# 745                            C#; JavaScript; SQL; VB.NET
# 748                                                      C
# 749             CoffeeScript; Java; JavaScript; PHP; Swift
# 750                                       Java; JavaScript
# 753                      C; JavaScript; Objective-C; Swift
# 755      C#; JavaScript; Python; TypeScript; VB.NET; Vi...
# 756                            C++; C#; JavaScript; VB.NET
# 757                             JavaScript; Python; R; SQL
# 758                                                     C#
# 759                   C#; JavaScript; PHP; SQL; TypeScript
# 760                               C#; JavaScript; PHP; SQL
# 762                                                C#; SQL
# 765                                                     C#
# 766                                   JavaScript; SQL; VBA
# 767                                                   Java
# 768                        JavaScript; Python; SQL; VB.NET
# 769            Assembly; C; CoffeeScript; Java; JavaScript
# 770                                      Java; Python; SQL
# 772                                JavaScript; Python; SQL
# 773                                 Java; PHP; Python; SQL
# 774                        C#; JavaScript; SQL; TypeScript
# 777                                            C; C++; SQL
# 778                             C#; JavaScript; Scala; SQL
# 779                                     C; Java; Ruby; SQL
# 780                                   JavaScript; PHP; SQL
# 781                               Groovy; Java; JavaScript
# 782                       C; C++; C#; JavaScript; PHP; SQL
# 784                                    C#; JavaScript; SQL
# 785                                C#; Go; Lua; TypeScript
# 786                                            Python; SQL
# 790                           JavaScript; PHP; Python; SQL
# 793             C#; Java; JavaScript; SQL; TypeScript; VBA
# 796                                   JavaScript; PHP; SQL
# 797                              C#; Java; JavaScript; SQL
# 798                                        C++; Java; Ruby
# 799                               JavaScript; Python; Ruby
# 800                         CoffeeScript; JavaScript; Rust
# 801                                JavaScript; Python; SQL
# 802                                 Java; JavaScript; Ruby
# 803                         JavaScript; Python; TypeScript
# 804                                            C++; Python
# 805                       Elixir; Objective-C; Ruby; Swift
# 806                     Java; JavaScript; PHP; Python; SQL
# 807                          C; C#; JavaScript; TypeScript
# 808         C; C++; C#; Java; JavaScript; PHP; Python; SQL
# 809                                                C++; C#
# 810                 C++; C#; JavaScript; Perl; Python; SQL
# 811                                                 R; SQL
# 813                                            Python; SQL
# 815      Assembly; C; C++; C#; Common Lisp; Go; Haskell...
# 816                                 JavaScript; TypeScript
# 817                           Assembly; C; C++; C#; Python
# 818                              Groovy; Java; Python; SQL
# 820                   C#; JavaScript; PHP; SQL; TypeScript
# 821                               C; C++; PHP; Python; SQL
# 822      Assembly; C; C++; C#; Java; JavaScript; Lua; P...
# 823                  C++; Common Lisp; Java; Python; Scala
# 825                 C; PHP; Python; VB.NET; Visual Basic 6
# 827                                         Go; JavaScript
# 829                    C; Groovy; Java; JavaScript; Python
# 831                                JavaScript; Python; SQL
# 832                               C#; Java; Perl; SQL; VBA
# 833      C#; Java; JavaScript; SQL; VB.NET; VBA; Visual...
# 834                     Java; JavaScript; Objective-C; SQL
# 835                                        Go; Objective-C
# 836                                      Java; Matlab; SQL
# 837      C; C++; C#; Dart; Go; Java; JavaScript; Object...
# 839                                C++; JavaScript; Python
# 841                C#; Common Lisp; JavaScript; SQL; Swift
# 842                                                C#; SQL
# 846                                                   Java
# 847                                          C++; C#; Java
# 848                                                     C#
# 849                        C#; Java; JavaScript; Ruby; SQL
# 850                                              C; Python
# 851                                  Java; JavaScript; PHP
# 853                         CoffeeScript; JavaScript; Ruby
# 854                                     JavaScript; Python
# 855                    Java; JavaScript; Objective-C; Ruby
# 856                                    C#; JavaScript; SQL
# 857      Java; JavaScript; Lua; PHP; Python; Ruby; SQL;...
# 858                                   JavaScript; PHP; SQL
# 859                                                 Python
# 860             C#; Java; JavaScript; PHP; SQL; TypeScript
# 861                             C; C++; JavaScript; Python
# 862                                                   Rust
# 865      C; C++; C#; Java; JavaScript; Perl; PHP; Pytho...
# 866                          JavaScript; Perl; PHP; Python
# 867                           C; C++; JavaScript; PHP; SQL
# 868                                              C; Python
# 869                                      JavaScript; Scala
# 871                               C; C++; C#; Python; Ruby
# 873                   C; C++; JavaScript; Objective-C; PHP
# 874                                       Java; JavaScript
# 876                                                C#; SQL
# 877                           C#; CoffeeScript; JavaScript
# 878                       C; C++; Java; JavaScript; Python
# 879      Assembly; C; C++; C#; JavaScript; PHP; TypeScr...
# 880                                      C; Matlab; Python
# 881                                                   Java
# 882      Assembly; C; C++; Java; JavaScript; PHP; SQL; VBA
# 883        C#; JavaScript; Objective-C; SQL; Swift; VB.NET
# 884                                                    SQL
# 886                                            C; C#; Java
# 888              Java; JavaScript; PHP; Python; SQL; Swift
# 889                                   JavaScript; PHP; SQL
# 890                               C#; JavaScript; PHP; SQL
# 893                 Clojure; Java; PHP; Python; Scala; SQL
# 895                                        JavaScript; PHP
# 896                             Java; JavaScript; PHP; SQL
# 897                            C#; JavaScript; SQL; VB.NET
# 898                                              Java; SQL
# 899                                                   Java
# 901               CoffeeScript; Java; JavaScript; PHP; SQL
# 902                             Java; JavaScript; PHP; SQL
# 903      Assembly; C; C++; Java; JavaScript; Perl; PHP;...
# 904                       C; C#; Python; R; Ruby; SQL; VBA
# 905                           Java; JavaScript; TypeScript
# 906                                        JavaScript; PHP
# 908                                                 Python
# 909                                            C++; Python
# 910             C; C++; Java; JavaScript; PHP; Python; SQL
# 912                    C#; JavaScript; R; Ruby; Scala; SQL
# 913                                  Java; JavaScript; SQL
# 914                                              C; C++; R
# 915                                   C#; Java; JavaScript
# 916                                         C#; JavaScript
# 917      C; Groovy; Java; JavaScript; Perl; Python; Sca...
# 919                                               PHP; SQL
# 920                    C; C++; C#; JavaScript; PHP; Python
# 921                  C; C++; Java; JavaScript; PHP; Python
# 922                                                     C#
# 923                                      Groovy; Ruby; SQL
# 924                                C; JavaScript; Lua; SQL
# 925                             Java; JavaScript; PHP; SQL
# 926                                        C++; JavaScript
# 927                                           C++; C#; SQL
# 929                       C#; JavaScript; PHP; Python; SQL
# 930                C#; JavaScript; SQL; TypeScript; VB.NET
# 931            Assembly; C; C++; Haskell; JavaScript; Rust
# 933                                  Java; JavaScript; SQL
# 934                                       Java; JavaScript
# 936                                       Go; Groovy; Java
# 937                                                C++; C#
# 938                                      C#; Haskell; Rust
# 939                                    C#; JavaScript; PHP
# 940                                             C; C++; C#
# 942                               Assembly; C; Common Lisp
# 944                                                     C#
# 948                                  JavaScript; PHP; Ruby
# 949                                                   Java
# 950                                C++; JavaScript; Python
# 953              Elixir; Java; JavaScript; Ruby; Rust; SQL
# 954                               C++; Common Lisp; Python
# 955                                         C; C++; Python
# 956                            C#; JavaScript; Python; SQL
# 957                                Elixir; JavaScript; PHP
# 958      Assembly; C; C++; Common Lisp; Clojure; Erlang...
# 959                                  C; C#; Visual Basic 6
# 961                                    C#; JavaScript; SQL
# 962                               Java; JavaScript; Python
# 964                                  Java; JavaScript; SQL
# 968                              C++; JavaScript; PHP; SQL
# 969                                                     C#
# 972                 Assembly; C; C++; Java; Matlab; Python
# 974                                        JavaScript; PHP
# 976                                JavaScript; PHP; Python
# 978                                                     C#
# 979                 Go; JavaScript; PHP; Python; Ruby; SQL
# 980      C; C++; C#; Java; JavaScript; Matlab; Perl; PH...
# 981                            Java; JavaScript; PHP; Ruby
# 982                                                  Scala
# 983                                              C++; Java
# 984                                            R; SQL; VBA
# 986                          Java; JavaScript; Ruby; Scala
# 987                     Assembly; C; C++; C#; Java; Python
# 988        C#; JavaScript; Python; SQL; TypeScript; VB.NET
# 989                                                 Python
# 990                                  C#; Java; SQL; VB.NET
# 991                                         C#; JavaScript
# 992      C; C++; C#; Erlang; Go; Java; Rust; SQL; TypeS...
# 995                                Java; Matlab; Python; R
# 997                                      C; C++; Perl; SQL
# 999                       C#; Java; JavaScript; TypeScript
# 1000                                   C; C#; Python; Ruby
# 1002                    C#; JavaScript; Python; TypeScript
# 1003                       C; C++; Java; Perl; Python; SQL
# 1004                       C#; JavaScript; SQL; TypeScript
# 1005                                             Java; SQL
# 1007                                       Java; Python; R
# 1008            C; CoffeeScript; JavaScript; Julia; Python
# 1009                                   C#; JavaScript; SQL
# 1010                      Java; JavaScript; Lua; Ruby; SQL
# 1011                  Groovy; Java; JavaScript; TypeScript
# 1012                        C++; C#; Java; JavaScript; Lua
# 1013                                          Haskell; PHP
# 1014              JavaScript; Objective-C; PHP; SQL; Swift
# 1015     C#; Java; JavaScript; PHP; Python; SQL; TypeSc...
# 1016                   C#; JavaScript; Lua; Python; R; SQL
# 1018        C; C++; Haskell; Java; JavaScript; Python; SQL
# 1019     Haskell; Java; JavaScript; Matlab; Perl; PHP; ...
# 1020                         C++; Java; JavaScript; Python
# 1021                                     Java; Ruby; Scala
# 1022                       C#; JavaScript; SQL; TypeScript
# 1023                        JavaScript; Objective-C; Swift
# 1024                                                  Java
# 1026                            C#; JavaScript; TypeScript
# 1028                      C#; Java; JavaScript; TypeScript
# 1030           CoffeeScript; JavaScript; Python; Ruby; SQL
# 1031                                                Python
# 1032                                 Java; JavaScript; SQL
# 1033     C++; C#; Java; JavaScript; PHP; Python; SQL; V...
# 1034                    JavaScript; PHP; Python; Ruby; SQL
# 1035                                  JavaScript; PHP; SQL
# 1036                      Java; Objective-C; Python; Swift
# 1037                                            JavaScript
# 1038                              Java; Python; Scala; SQL
# 1039                    Java; JavaScript; PHP; Python; SQL
# 1040                   Java; JavaScript; PHP; Python; Ruby
# 1043                           C#; JavaScript; Python; SQL
# 1044                       C#; JavaScript; SQL; TypeScript
# 1045                                                   C++
# 1046                                           Python; SQL
# 1051                Elixir; Go; JavaScript; PHP; Rust; SQL
# 1052                    Java; JavaScript; Lua; Python; SQL
# 1053                         JavaScript; Perl; Python; SQL
# 1054           Assembly; Java; JavaScript; SQL; TypeScript
# 1055                                                  Java
# 1057                                     Groovy; Java; SQL
# 1059                             C#; Java; JavaScript; SQL
# 1060     C; C++; C#; Java; JavaScript; Objective-C; PHP...
# 1062                                   Haskell; Scala; SQL
# 1063                                Java; JavaScript; Rust
# 1064                                        C; C++; Python
# 1066                   C#; JavaScript; SQL; Visual Basic 6
# 1067                  JavaScript; Perl; PHP; Python; Scala
# 1069                                       JavaScript; PHP
# 1070                                   C#; JavaScript; SQL
# 1071                                  Go; Java; JavaScript
# 1072                                 Java; JavaScript; SQL
# 1073                             C#; Java; JavaScript; SQL
# 1075                   Java; JavaScript; Objective-C; Ruby
# 1076                                   C#; JavaScript; SQL
# 1077                                             Java; PHP
# 1078                                                Python
# 1079                                                    C#
# 1080                                                   C++
# 1081                                            Java; Ruby
# 1083                                                  Java
# 1084                               C++; JavaScript; Python
# 1085                            C#; JavaScript; SQL; Swift
# 1086                            C#; JavaScript; TypeScript
# 1088        C#; Go; Java; JavaScript; PHP; SQL; TypeScript
# 1090                                 Java; JavaScript; SQL
# 1091                                 Java; JavaScript; SQL
# 1093                                                   C++
# 1094                                       JavaScript; SQL
# 1095                          Java; JavaScript; PHP; Scala
# 1096                      C#; JavaScript; SQL; VB.NET; VBA
# 1097                                             Python; R
# 1101           C++; Java; JavaScript; PHP; SQL; TypeScript
# 1103                                             Java; PHP
# 1104                   C#; JavaScript; Python; SQL; VB.NET
# 1105                                            JavaScript
# 1111                                 Java; JavaScript; SQL
# 1113                                    JavaScript; Python
# 1116                                      C++; Java; Scala
# 1117                                            JavaScript
# 1118                            Java; JavaScript; PHP; SQL
# 1119                            Java; JavaScript; PHP; SQL
# 1120                       Java; JavaScript; Python; Scala
# 1121                             C#; JavaScript; Ruby; SQL
# 1123                                   C; Java; TypeScript
# 1124         C; C++; C#; Go; Java; JavaScript; Python; SQL
# 1125                              Groovy; Java; Scala; SQL
# ...
# 51080                        Java; JavaScript; Python; SQL
# 51081    Assembly; C; CoffeeScript; Java; JavaScript; O...
# 51082                                      C++; Java; Perl
# 51083                                           JavaScript
# 51084                                 C#; PHP; SQL; VB.NET
# 51085                        C; C++; Go; Java; Python; SQL
# 51086                                  Haskell; JavaScript
# 51087                                              C#; SQL
# 51088                                 JavaScript; PHP; SQL
# 51089                      C#; JavaScript; SQL; TypeScript
# 51090                                         Groovy; Java
# 51091    C; C++; C#; Haskell; Java; JavaScript; Matlab;...
# 51092                   Java; JavaScript; PHP; Python; VBA
# 51093                     C++; C#; Java; Python; Ruby; SQL
# 51094                                  C#; JavaScript; SQL
# 51095        C++; Java; JavaScript; PHP; Python; Ruby; SQL
# 51096                 Assembly; Java; JavaScript; PHP; SQL
# 51097                       JavaScript; Python; TypeScript
# 51098                                                    R
# 51099                        Java; JavaScript; Python; SQL
# 51100                 C#; JavaScript; SQL; TypeScript; VBA
# 51101                                      Haskell; Python
# 51102                                  C#; JavaScript; SQL
# 51103         JavaScript; PHP; SQL; VB.NET; Visual Basic 6
# 51104                                  C#; JavaScript; SQL
# 51105                                          Java; Scala
# 51106                      C; C++; JavaScript; Python; SQL
# 51107                       CoffeeScript; JavaScript; Ruby
# 51108             JavaScript; PHP; Python; SQL; TypeScript
# 51109                               C#; JavaScript; Python
# 51110     Assembly; C; C++; JavaScript; Objective-C; Swift
# 51111                                            Java; SQL
# 51112                                  C#; JavaScript; SQL
# 51113                                                  C++
# 51114                                           C#; VB.NET
# 51115              C++; Java; JavaScript; PHP; Python; SQL
# 51116                             Java; Objective-C; Swift
# 51117                     Assembly; C; Common Lisp; Python
# 51119                                                 Java
# 51120                   JavaScript; Perl; PHP; Python; SQL
# 51122                             C; C++; Go; Java; Python
# 51124                         JavaScript; PHP; Python; VBA
# 51125                                  C#; JavaScript; SQL
# 51126                                                  SQL
# 51127                                             C#; Java
# 51128                                  VBA; Visual Basic 6
# 51129                                          C; PHP; SQL
# 51130                                  C#; JavaScript; SQL
# 51131    C#; CoffeeScript; Groovy; Java; JavaScript; Ob...
# 51132            Java; JavaScript; Objective-C; SQL; Swift
# 51133                                                   C#
# 51134                                           C#; R; SQL
# 51135                              JavaScript; PHP; Python
# 51136                         C++; JavaScript; Python; SQL
# 51137          C++; Go; Java; JavaScript; PHP; Python; SQL
# 51138    C; C++; C#; Java; JavaScript; Python; Ruby; SQ...
# 51139                Java; JavaScript; PHP; Python; R; SQL
# 51140                   C#; Go; Java; JavaScript; PHP; SQL
# 51141                         Java; VB.NET; Visual Basic 6
# 51142                                   JavaScript; Python
# 51144                                      JavaScript; PHP
# 51145                                   Objective-C; Swift
# 51146                                                  C++
# 51147                           JavaScript; Matlab; Python
# 51148                            Clojure; Java; JavaScript
# 51151                                        C#; Java; Lua
# 51152     Assembly; C#; Java; JavaScript; PHP; SQL; VB.NET
# 51153                         Java; JavaScript; TypeScript
# 51154                                            C; Python
# 51156                   C; C++; JavaScript; Perl; PHP; SQL
# 51158                             SQL; VBA; Visual Basic 6
# 51159                             CoffeeScript; JavaScript
# 51160                                 JavaScript; PHP; SQL
# 51161                           C; C++; JavaScript; Python
# 51162          C#; JavaScript; SQL; VB.NET; Visual Basic 6
# 51163                                                 Java
# 51164                                           JavaScript
# 51165    C; JavaScript; PHP; Python; SQL; VB.NET; Visua...
# 51166                  CoffeeScript; JavaScript; Perl; PHP
# 51167                                 JavaScript; PHP; SQL
# 51168                                          Python; SQL
# 51169                           C#; JavaScript; TypeScript
# 51170                          C; C++; SQL; Visual Basic 6
# 51171                                          Java; Swift
# 51173                                       C#; JavaScript
# 51174                                         C++; C#; SQL
# 51175                Assembly; C; Java; JavaScript; Python
# 51176               C#; Java; JavaScript; PHP; Python; SQL
# 51177                             Java; JavaScript; Python
# 51178      C#; JavaScript; Python; SQL; TypeScript; VB.NET
# 51179                                           JavaScript
# 51181                                         C; Java; SQL
# 51182                                  C#; JavaScript; SQL
# 51183                                     C; C++; C#; Java
# 51184                              Java; JavaScript; Swift
# 51186    C#; CoffeeScript; Java; Python; Ruby; SQL; VB.NET
# 51187                         Assembly; C; C++; JavaScript
# 51188                         JavaScript; PHP; Python; SQL
# 51189    Assembly; C; C++; C#; Java; JavaScript; PHP; P...
# 51190                                                 Ruby
# 51191                             C#; JavaScript; SQL; VBA
# 51192                       Java; JavaScript; Python; Ruby
# 51193                             C; C++; C#; Java; Python
# 51194    C; Go; JavaScript; Perl; PHP; Python; Ruby; SQ...
# 51195               C++; C#; Java; JavaScript; Matlab; SQL
# 51196                                       C++; Python; R
# 51197                                 JavaScript; PHP; SQL
# 51198       C; C++; Common Lisp; F#; Haskell; Java; Python
# 51199                                JavaScript; PHP; Ruby
# 51200    CoffeeScript; Elixir; Hack; Haskell; Java; Jav...
# 51201                          C#; JavaScript; PHP; Python
# 51202              Java; JavaScript; Ruby; SQL; TypeScript
# 51203                                  C#; JavaScript; SQL
# 51204    C#; Java; JavaScript; Python; Ruby; SQL; TypeS...
# 51205                                         C; Java; PHP
# 51206                                      JavaScript; SQL
# 51207                      C++; Objective-C; Python; Swift
# 51208                                        C++; C#; Java
# 51209                               C; C++; Java; PHP; SQL
# 51210                        Groovy; Java; JavaScript; Lua
# 51211    C; C++; CoffeeScript; Elixir; Go; Haskell; Jav...
# 51212    C++; C#; Haskell; Java; JavaScript; Objective-...
# 51213                                Java; PHP; Scala; SQL
# 51214                   Java; JavaScript; PHP; Python; SQL
# 51215                                           JavaScript
# 51216                                        C#; Java; SQL
# 51217                                                   C#
# 51218                                             C#; Java
# 51221                                       C; PHP; Python
# 51224                         Java; JavaScript; Scala; SQL
# 51229                                     Go; Java; Python
# 51230                              JavaScript; Python; SQL
# 51231                                      JavaScript; PHP
# 51232                                                 Java
# 51233              JavaScript; Matlab; PHP; Python; R; SQL
# 51235                        C; C++; Java; JavaScript; PHP
# 51236    C; C++; C#; CoffeeScript; Clojure; Dart; Java;...
# 51237                                C; C++; C#; Java; SQL
# 51238                                 JavaScript; PHP; SQL
# 51239             Elixir; JavaScript; PHP; SQL; TypeScript
# 51240                                  Assembly; Java; SQL
# 51241    C; C++; C#; Go; Java; JavaScript; Lua; Python;...
# 51242                                    C; C++; Java; SQL
# 51243                          C; C++; Haskell; JavaScript
# 51244                                           C#; Python
# 51245                     Java; JavaScript; Matlab; Python
# 51246           C#; Clojure; Java; JavaScript; Python; SQL
# 51247                                            C; Python
# 51248       C; C#; Java; JavaScript; Python; R; Scala; SQL
# 51250    Java; JavaScript; Julia; Matlab; Python; R; SQ...
# 51251                                                  SQL
# 51253                    C#; Groovy; Java; JavaScript; SQL
# 51254                              JavaScript; Python; SQL
# 51255                 C#; Dart; Java; JavaScript; SQL; VBA
# 51256                                                    C
# 51257                           Java; JavaScript; PHP; SQL
# 51258                              Java; Scala; TypeScript
# 51259                                 C#; Java; JavaScript
# 51260                         Groovy; JavaScript; PHP; SQL
# 51262                                          Assembly; C
# 51264                                       Java; PHP; SQL
# 51265                                 JavaScript; PHP; SQL
# 51266           C#; Java; JavaScript; PHP; SQL; TypeScript
# 51267                       Groovy; JavaScript; Scala; SQL
# 51268    C; Java; JavaScript; Objective-C; Perl; Ruby; SQL
# 51269                           C++; Java; JavaScript; SQL
# 51270    C++; C#; Java; JavaScript; Objective-C; PHP; R...
# 51271                          C#; JavaScript; SQL; VB.NET
# 51272                      Go; Haskell; Java; Python; Rust
# 51274                            C#; Java; JavaScript; SQL
# 51275                      C#; JavaScript; SQL; TypeScript
# 51277                    C++; C#; JavaScript; Python; Rust
# 51278                                           JavaScript
# 51279                                      C#; PHP; R; SQL
# 51280                                           JavaScript
# 51281                                           JavaScript
# 51282    C++; Java; JavaScript; Perl; PHP; Python; Ruby...
# 51283                           JavaScript; Perl; PHP; SQL
# 51284                           JavaScript; PHP; Ruby; SQL
# 51285                          C#; Java; Matlab; Python; R
# 51286                                           C; C++; C#
# 51287                                 JavaScript; SQL; VBA
# 51289                                          PHP; Python
# 51290                                      JavaScript; PHP
# 51291                        Java; JavaScript; Python; SQL
# 51292                      C++; Java; JavaScript; PHP; SQL
# 51293    C#; Go; Java; JavaScript; Python; R; SQL; Type...
# 51294                              C; C++; JavaScript; Lua
# 51296                          C#; JavaScript; SQL; VB.NET
# 51297                                           JavaScript
# 51298                          C; C#; JavaScript; PHP; SQL
# 51299                 C#; SQL; VB.NET; VBA; Visual Basic 6
# 51300                                     Java; JavaScript
# 51301                          C#; JavaScript; SQL; VB.NET
# 51302                       Java; JavaScript; Python; Ruby
# 51305                                 JavaScript; PHP; SQL
# 51306                                                  C++
# 51307       C; Groovy; Java; JavaScript; Perl; Python; SQL
# 51308                        Groovy; Java; JavaScript; SQL
# 51309                                   JavaScript; Python
# 51310                           Java; JavaScript; PHP; SQL
# 51311                                            C++; Java
# 51312                        Groovy; Java; JavaScript; SQL
# 51313                         Java; Matlab; Python; R; SQL
# 51315                                  Clojure; TypeScript
# 51316                                   JavaScript; Python
# 51317                  Groovy; Java; JavaScript; Perl; SQL
# 51318                                                  SQL
# 51319                                  C; C++; Go; Haskell
# 51321     C; C++; Hack; Java; JavaScript; PHP; Python; SQL
# 51322                                       Python; R; SQL
# 51323    C++; Groovy; Java; JavaScript; Python; Scala; ...
# 51325                        Java; JavaScript; Objective-C
# 51326                 C; C#; Java; JavaScript; Python; SQL
# 51327    Assembly; Clojure; JavaScript; Python; Scala; SQL
# 51328                                       C#; JavaScript
# 51329                                         C; C++; Java
# 51330                                                 Java
# 51331                             C; Java; JavaScript; SQL
# 51334                          JavaScript; PHP; TypeScript
# 51335                 C#; JavaScript; SQL; TypeScript; VBA
# 51336                               PHP; Python; Ruby; SQL
# 51337                                           JavaScript
# 51338                                      C#; SQL; VB.NET
# 51339                                 JavaScript; PHP; SQL
# 51340                                               Python
# 51342                         C++; Java; JavaScript; Swift
# 51343               C; C++; C#; Java; JavaScript; PHP; SQL
# 51344                      C#; JavaScript; SQL; TypeScript
# 51345                                                  C++
# 51347                                 C; Java; PHP; Python
# 51348                                        C; C#; Python
# 51349                             Objective-C; Ruby; Swift
# 51350                         C#; Java; JavaScript; Python
# 51351    C; C++; C#; JavaScript; Lua; Objective-C; Perl...
# 51352          C++; C#; Java; JavaScript; PHP; Python; SQL
# 51354    Assembly; C; C++; Java; Matlab; PHP; SQL; VB.N...
# 51355              C#; Elixir; F#; JavaScript; Python; SQL
# 51356                  C#; Java; JavaScript; PHP; SQL; VBA
# 51358           Java; JavaScript; PHP; SQL; Visual Basic 6
# 51359                                 C#; PHP; Python; SQL
# 51360                                Java; JavaScript; SQL
# 51361                                               C; PHP
# 51362                    JavaScript; Objective-C; PHP; SQL
# 51363                        Java; JavaScript; Python; SQL
# 51364            C++; C#; JavaScript; PHP; SQL; TypeScript
# 51365                                                  VBA
# 51367    Assembly; C; C++; Java; JavaScript; PHP; Pytho...
# 51368                                          Objective-C
# 51369                      C; C++; JavaScript; Python; SQL
# 51370                                      JavaScript; PHP
# 51371                               Go; JavaScript; Python
# 51373    C; C++; JavaScript; Objective-C; PHP; Python; ...
# 51374                        C++; C#; JavaScript; Lua; PHP
# 51375                      C#; JavaScript; SQL; TypeScript
# 51376                      C; C#; Java; Python; SQL; Swift
# 51377                        Groovy; Java; JavaScript; SQL
# 51378               JavaScript; Objective-C; Python; Swift
# 51379                                               Matlab
# 51380                C++; C#; Perl; Ruby; SQL; VB.NET; VBA
# 51381                                   JavaScript; Python
# 51382                           C#; JavaScript; TypeScript
# 51383             JavaScript; Objective-C; PHP; SQL; Swift
# 51384                                           JavaScript
# 51385                  C#; JavaScript; PHP; Python; R; SQL
# 51386                  C++; C#; Java; JavaScript; PHP; SQL
# 51387             C#; JavaScript; Python; SQL; VB.NET; VBA
# 51388                                            Java; SQL
# 51390                               JavaScript; PHP; Swift
# 51391           Java; JavaScript; PHP; Python; Ruby; Swift
# Name: HaveWorkedLanguage, dtype: object

# %%
# Identify the type of languages used in a year
All_languages = []
for sublist in language.str.split(";",expand=False).values.tolist():
    for item in sublist:
        All_languages.append(item.replace(" ", ""))

language_type = list(set(All_languages)) # Select unique type of languages

# Calculate the frequency of each type of language
language_frequency =[]
for language_type_ in range(len(language_type)):
    language_frequency.append(All_languages.count(language_type[language_type_]))


# Sort in decreasing order the most used programming language
index_sort = np.argsort(language_frequency)
index_sort
language_type_sorted = []
language_frequency_sorted = []
for index in index_sort:
    language_type_sorted.append(language_type[index])
    language_frequency_sorted.append(language_frequency[index])

# Show frequency bar for the top 5
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(language_type_sorted[-5:],language_frequency_sorted[-5:])
plt.title('The five most popular programming language in ' + str(year))
plt.show()

# %%
index_sort
language_type_sorted = []
for index in index_sort:
    language_type_sorted.append(language_type[index])
language_type_sorted
# Out:
# ['Hack',
#  'Julia',
#  'Dart',
#  'CommonLisp',
#  'Erlang',
#  'Smalltalk',
#  'Elixir',
#  'Clojure',
#  'Rust',
#  'F#',
#  'Haskell',
#  'Lua',
#  'VisualBasic6',
#  'CoffeeScript',
#  'Groovy',
#  'Scala',
#  'Go',
#  'Matlab',
#  'VBA',
#  'Perl',
#  'R',
#  'Assembly',
#  'VB.NET',
#  'Objective-C',
#  'Swift',
#  'Ruby',
#  'TypeScript',
#  'C',
#  'C++',
#  'PHP',
#  'Python',
#  'C#',
#  'Java',
#  'SQL',
#  'JavaScript']

# %%
FormalEducation_exist = []
Features = pd.DataFrame()
for year in years:
    print(PathName  + FileNames[2020 - year] + '.csv')
    df = pd.read_csv(PathName  + FileNames[2020 - year] + '.csv',engine='python')
    try:
        df.FormalEducation
        print(df.columns)
        FormalEducation_exist.append(True)
        
    except: 
        FormalEducation_exist.append(False)
        print(df.columns)
# Out:
# ./Dataset/2011 Stack Overflow Survey Results.csv
# Index(['What Country or Region do you live in?',
#        'Which US State or Territory do you live in?', 'How old are you?',
#        'How many years of IT/Programming experience do you have?',
#        'How would you best describe the industry you work in?',
#        'Which best describes the size of your company?',
#        'Which of the following best describes your occupation?',
#        'How likely is it that a recommendation you make will be acted upon?',
#        'What is your involvement in purchasing? You can choose more than 1.',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14',
#        'What types of purchases are you involved in?', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'What is your budget for outside expenditures (hardware, software, consulting, etc) for 2011?',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'What type of project are you developing?',
#        'Which languages are you proficient in?', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42',
#        'What operating system do you use the most?',
#        'Please rate your job/career satisfaction',
#        'Including bonus, what is your annual compensation in USD?',
#        'Which technology products do you own? (You can choose more than one)',
#        'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50',
#        'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54',
#        'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58',
#        'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62',
#        'In the last 12 months, how much money have you spent on personal technology-related purchases? ',
#        'Which of our sites do you frequent most?'],
#       dtype='object')
# ./Dataset/2012 Stack Overflow Survey Results.csv
# Index(['What Country or Region do you live in?',
#        'Which US State or Territory do you live in?', 'How old are you?',
#        'How many years of IT/Programming experience do you have?',
#        'How would you best describe the industry you currently work in?',
#        'Which best describes the size of your company?',
#        'Which of the following best describes your occupation?',
#        'What is your involvement in purchasing products or services for the company you work for? (You can choose more than one)',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'What types of purchases are you involved in?',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19',
#        'What is your budget for outside expenditures (hardware, software, consulting, etc) for 2011?',
#        'What type of project are you developing?',
#        'Which languages are you proficient in?', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Which desktop operating system do you use the most?',
#        'What best describes your career / job satisfaction? ',
#        'Including bonus, what is your annual compensation in USD?',
#        'Have you visited / Are you aware of Stack Overflow Careers?',
#        'Do you have a Stack Overflow Careers Profile?',
#        'You answered you don't have a Careers profile, can you elaborate why?',
#        'Unnamed: 43',
#        'Which technology products do you own? (You can choose more than one)',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
#        'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60',
#        'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63',
#        'In the last 12 months, how much money have you spent on personal technology-related purchases? ',
#        'Please rate the advertising you've seen on Stack Overflow',
#        'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69',
#        'Unnamed: 70',
#        'What advertisers do you remember seeing on Stack Overflow?',
#        'What is your current Stack Overflow reputation?',
#        'Which of our sites do you frequent most?', 'Unnamed: 74'],
#       dtype='object')
# ./Dataset/2013 Stack Overflow Survey Responses.csv
# Index(['What Country or Region do you live in?',
#        'Which US State or Territory do you live in?', 'How old are you?',
#        'How many years of IT/Programming experience do you have?',
#        'How would you best describe the industry you currently work in?',
#        'How many people work for your company?',
#        'Which of the following best describes your occupation?',
#        'Including yourself, how many developers are employed at your company?',
#        'How large is the team that you work on?',
#        'What other departments / roles do you interact with regularly?',
#        ...
#        'Unnamed: 118', 'Unnamed: 119', 'Unnamed: 120', 'Unnamed: 121',
#        'What advertisers do you remember seeing on Stack Overflow?',
#        'What is your current Stack Overflow reputation?',
#        'How do you use Stack Overflow?', 'Unnamed: 125', 'Unnamed: 126',
#        'Unnamed: 127'],
#       dtype='object', length=128)
# ./Dataset/2014 Stack Overflow Survey Responses.csv
# Index(['What Country do you live in?', 'Unnamed: 1',
#        'Which US State or Territory do you live in?', 'How old are you?',
#        'What is your gender?',
#        'How many years of IT/Programming experience do you have?',
#        'Which of the following best describes your occupation?',
#        'Including bonus, what is your annual compensation in USD?',
#        'How would you best describe the industry you currently work in?',
#        'How many developers are employed at your company?',
#        ...
#        'Did you participate in the Apptivate contest?',
#        'What advertisers do you remember seeing on Stack Overflow?',
#        'What is your current Stack Overflow reputation?',
#        'How do you use Stack Overflow?', 'Unnamed: 114', 'Unnamed: 115',
#        'Unnamed: 116', 'Unnamed: 117', 'Unnamed: 118',
#        'How often do you find solutions to your programming problems on Stack Overflow without asking a new question?'],
#       dtype='object', length=120)
# ./Dataset/2015 Stack Overflow Developer Survey Responses.csv
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Select all that apply',
#        'Unnamed: 9',
#        ...
#        'Unnamed: 212', 'Unnamed: 213', 'Select all that apply.7',
#        'Unnamed: 215', 'Unnamed: 216', 'Unnamed: 217', 'Unnamed: 218',
#        'Unnamed: 219', 'Unnamed: 220', 'Unnamed: 221'],
#       dtype='object', length=222)
# ./Dataset/2016 Stack Overflow Survey Responses.csv
# Index(['Unnamed: 0', 'collector', 'country', 'un_subregion', 'so_region',
#        'age_range', 'age_midpoint', 'gender', 'self_identification',
#        'occupation', 'occupation_group', 'experience_range',
#        'experience_midpoint', 'salary_range', 'salary_midpoint',
#        'big_mac_index', 'tech_do', 'tech_want', 'aliens',
#        'programming_ability', 'employment_status', 'industry',
#        'company_size_range', 'team_size_range', 'women_on_team', 'remote',
#        'job_satisfaction', 'job_discovery', 'dev_environment',
#        'commit_frequency', 'hobby', 'dogs_vs_cats', 'desktop_os',
#        'unit_testing', 'rep_range', 'visit_frequency', 'why_learn_new_tech',
#        'education', 'open_to_new_job', 'new_job_value', 'job_search_annoyance',
#        'interview_likelihood', 'how_to_improve_interview_process',
#        'star_wars_vs_star_trek', 'agree_tech', 'agree_notice',
#        'agree_problemsolving', 'agree_diversity', 'agree_adblocker',
#        'agree_alcohol', 'agree_loveboss', 'agree_nightcode', 'agree_legacy',
#        'agree_mars', 'important_variety', 'important_control',
#        'important_sameend', 'important_newtech', 'important_buildnew',
#        'important_buildexisting', 'important_promotion',
#        'important_companymission', 'important_wfh', 'important_ownoffice',
#        'developer_challenges', 'why_stack_overflow'],
#       dtype='object')
# ./Dataset/survey_results_public_2017.csv
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=154)
# ./Dataset/survey_results_public_2018.csv
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)
# ./Dataset/survey_results_public_2019.csv
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')
# ./Dataset/survey_results_public_2020.csv
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
FormalEducation_exist
# Out:
# [False, False, False, False, False, False, True, True, False, False]

# %% [markdown]
# Now, it is defined the function _clean_data_ to clean up the dataset.

# %%
def clean_data(df):
    '''
    INPUT
    df - pandas dataframe 
    
    OUTPUT
    X - A matrix holding all of the variables you want to consider when predicting the response
    y - the corresponding response vector
    
    Perform to obtain the correct X and y objects
    This function cleans df using the following steps to produce X and y:
    1. Drop all the rows with no salaries
    2. Create X as all the columns that are not the Salary column
    3. Create y as the Salary column
    4. Drop the Salary, Respondent, and the ExpectedSalary columns from X
    5. For each numeric variable in X, fill the column with the mean value of the column.
    6. Create dummy columns for all the categorical variables in X, drop the original columns
    '''
    # Drop all the rows with no salaries
    df = df.dropna(subset = ['Salary'], axis = 0)

   
    # Create y as the Salary column
    y = df['Salary']
    
    # Drop the Salary, Respondent, and the ExpectedSalary columns from X
    df = df.drop(['Salary','Respondent','ExpectedSalary'], axis=1)
    
    # For each numeric variable in X, fill the column with the mean value of the column.
    num_vars = df.select_dtypes(include = ['float', 'int']).columns
    for col in num_vars:
        df[col].fillna((df[col].mean()), inplace=True)

    # Create dummy columns for all the categorical variables in X, drop the original columns
    cat_vars = df.select_dtypes(include = ['object']).copy().columns
    for cols in cat_vars:
        df = pd.concat([df.drop(cols,axis = 1),pd.get_dummies(df[cols], prefix=cols, prefix_sep='_', drop_first=True)],axis = 1)

    X = df
    
    return X, y
    
#Use the function to create X and y
X, y = clean_data(df)
